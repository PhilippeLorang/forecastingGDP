# %%
import numpy as np
import pandas as pd
import seaborn as sns
from fredapi import Fred

# %%
codes ={
        'gdp':'GDPC1',
        'prod_indus':'INDPRO',
        #'Manufacturing Production'
        'BusinessExpectations':'ATLSBUSRGEP',
        'Capacity_Utilization':'TCU',
        #'manuf_ISM':'ISM'

        'Manufacturers_New_Orders':'AMTMNO',
        'New_Orders_Non_defense_capital_good_ex_air':'NEWORDER',
        #'Building_permits'
        #'Housing_Starts'
        #'Construction Spending'
        #'new_car'
        #'Crude Oil Production'
        'Chicago_Fed_Activity_Index':'CFNAI',        
        'University_of_Michigan_Consumer_Sentiment':'UMCSENT',
         #Philadelphia FedManufacturing Index
 
        'Advance_Retail_Sales':'MARTSMPCSM44000USS',    
        'Real_Disposable_Personal_Income':'DSPIC96',
        'Personal_Consumption_Expenditure':'PCEC96',

        #Initial Jobless Claims
        'Unemployment_Rate':'UNRATE',
        'Employment_Leve':'CE16OV',
        'Non_farm_payroll':'PAYEMS',
        'Not in Labor Force':'LNU05026648',

        #'Average Hourly Wages'
        'Consumer_Price_Index':'CPIAUCSL',
        'Personal_Consumption_Expenditure_ex_food':'PCEPILFE',
        'Producer_Price_Index':'PPIACO',
        #'Oil Price'
        #'Unit Labour Cost'
        'Imports_Goods_Services':'IEAMGSN',
        'Exports_Goods_Services':'IEAXGS',
        'Imports_Goods_from_China':'IMPCH',
        
        'BofA_US_High_Yield_Index':'BAMLH0A0HYM2',
        'S&P_500':'SP500',
        'VIX_Volatility':'VIXCLS',
        '10YUST':'DGS10',
        '10YUST_2YUST':'T10Y2Y',
        'US_Dollar Index':'DTWEXAFEGS'
       }

# %%
CODES=list(codes.values())

# %%
CODES
# Out:
# ['GDPC1',
#  'INDPRO',
#  'ATLSBUSRGEP',
#  'TCU',
#  'AMTMNO',
#  'NEWORDER',
#  'CFNAI',
#  'UMCSENT',
#  'MARTSMPCSM44000USS',
#  'DSPIC96',
#  'PCEC96',
#  'UNRATE',
#  'CE16OV',
#  'PAYEMS',
#  'LNU05026648',
#  'CPIAUCSL',
#  'PCEPILFE',
#  'PPIACO',
#  'IEAMGSN',
#  'IEAXGS',
#  'IMPCH',
#  'BAMLH0A0HYM2',
#  'SP500',
#  'VIXCLS',
#  'DGS10',
#  'T10Y2Y',
#  'DTWEXAFEGS']

# %%
# CODES = [
#     'GDPC1',
#     'AMTMNO',
#     'ATLSBUSRGEP',
# ]

TARGET = 'GDPC1'

FREQUENCY = 'q'

# %%
fred = Fred()

# %%
data = {}
for code in CODES:
    data[code] = fred.get_series(code, frequency=FREQUENCY)

# %%
data_df = pd.DataFrame(data)
data_df
# Out:
#                 GDPC1   INDPRO  ATLSBUSRGEP      TCU    AMTMNO  NEWORDER  \
# 1913-01-01        NaN      NaN          NaN      NaN       NaN       NaN
# 1913-04-01        NaN      NaN          NaN      NaN       NaN       NaN
# 1913-07-01        NaN      NaN          NaN      NaN       NaN       NaN
# 1913-10-01        NaN      NaN          NaN      NaN       NaN       NaN
# 1914-01-01        NaN      NaN          NaN      NaN       NaN       NaN
# ...               ...      ...          ...      ...       ...       ...
# 2020-04-01  17302.511  87.0691    -0.182590  65.5858  385218.0   61823.0
# 2020-07-01  18596.521  95.4610     1.773583  71.9489  443916.0   67542.0
# 2020-10-01  18794.426  97.3639     3.110526  73.4144  460614.0   70603.0
# 2021-01-01  19086.375  98.2332     4.863104  74.0632  482809.0   72618.0
# 2021-04-01        NaN      NaN          NaN      NaN       NaN       NaN
#
#             CFNAI  UMCSENT  MARTSMPCSM44000USS  DSPIC96  ...  PPIACO  \
# 1913-01-01    NaN      NaN                 NaN      NaN  ...    12.0
# 1913-04-01    NaN      NaN                 NaN      NaN  ...    11.9
# 1913-07-01    NaN      NaN                 NaN      NaN  ...    12.1
# 1913-10-01    NaN      NaN                 NaN      NaN  ...    12.1
# 1914-01-01    NaN      NaN                 NaN      NaN  ...    11.8
# ...           ...      ...                 ...      ...  ...     ...
# 2020-04-01  -2.40     74.1                 3.9  16630.1  ...   188.4
# 2020-07-01   1.39     75.7                 1.2  15851.4  ...   194.3
# 2020-10-01   0.53     79.8                -0.6  15541.0  ...   198.4
# 2021-01-01   0.59     80.2                 5.1  17530.3  ...   209.9
# 2021-04-01    NaN      NaN                 NaN      NaN  ...     NaN
#
#              IEAMGSN    IEAXGS         IMPCH  BAMLH0A0HYM2    SP500  VIXCLS  \
# 1913-01-01       NaN       NaN           NaN           NaN      NaN     NaN
# 1913-04-01       NaN       NaN           NaN           NaN      NaN     NaN
# 1913-07-01       NaN       NaN           NaN           NaN      NaN     NaN
# 1913-10-01       NaN       NaN           NaN           NaN      NaN     NaN
# 1914-01-01       NaN       NaN           NaN           NaN      NaN     NaN
# ...              ...       ...           ...           ...      ...     ...
# 2020-04-01  612162.0  454987.0  34989.852203          7.15  2931.69   34.49
# 2020-07-01  721595.0  523259.0  40881.278455          5.37  3319.83   25.81
# 2020-10-01  773074.0  558795.0  43817.418659          4.55  3554.50   25.62
# 2021-01-01  757431.0  584450.0  37789.200157          3.62  3865.71   23.20
# 2021-04-01       NaN       NaN           NaN          3.27  4179.99   18.11
#
#             DGS10  T10Y2Y  DTWEXAFEGS
# 1913-01-01    NaN     NaN         NaN
# 1913-04-01    NaN     NaN         NaN
# 1913-07-01    NaN     NaN         NaN
# 1913-10-01    NaN     NaN         NaN
# 1914-01-01    NaN     NaN         NaN
# ...           ...     ...         ...
# 2020-04-01   0.69    0.49    112.4061
# 2020-07-01   0.65    0.51    107.2881
# 2020-10-01   0.86    0.71    105.1863
# 2021-01-01   1.34    1.20    103.4882
# 2021-04-01   1.60    1.42    102.8897
#
# [434 rows x 27 columns]

# %%
data_growth=data_df[['GDPC1','INDPRO', 'ATLSBUSRGEP', 'TCU', 'AMTMNO','NEWORDER','CFNAI','UMCSENT']]

# %%
sns.pairplot(data_growth,hue=None)

# %%
sns.heatmap(data_growth.corr())
# Out:
# <AxesSubplot:>
